# %% [markdown]
# # Aero-Topo Kaggle Execution Notebook
# ### Smoke-Resilient UAV RGB+Thermal Fusion, Depth Anything V2 & 3D Topographical Projection
#
# This notebook runs the Aero-Topo pipeline in Kaggle (T4 GPU environment) using pre-mounted datasets under `/kaggle/input`.

# %%
# 1. Environment & Path Setup
import os
import glob
import sys
import torch

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")

KAGGLER_INPUT = "/kaggle/input"
OUTPUT_DIR = "/kaggle/working/aero_topo_results"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Search for FLAME 3 or IGNITE datasets
dataset_matches = glob.glob(f"{KAGGLER_INPUT}/**/*flame*", recursive=True) + glob.glob(f"{KAGGLER_INPUT}/**/*ignite*", recursive=True)
print("Discovered Kaggle Datasets:", dataset_matches)

# %%
# 2. Install minimal extra dependencies if required
# !pip install -q trimesh tifffile transformers huggingface_hub

# %%
# 3. Run Pretrained Model Checkpoint Downloader
# !python scripts/download_models.py

# %%
# 4. Sample Inference Execution
from app.models.ff_fusion import FFFusionModel
from app.models.depth_anything import DepthAnythingV2Model
from app.preprocessing.alignment import align_image_pair
from app.preprocessing.rgb import load_rgb_image
from app.preprocessing.thermal import load_thermal_image

print("Models Initialized Successfully. Output directory:", OUTPUT_DIR)
